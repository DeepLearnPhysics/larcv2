# %%
from __future__ import print_function

# %matplotlib inline
#%pylab
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from larcv import larcv
larcv.load_pyutil
from ROOT import TChain

# %%
for plane in xrange(3):

    ch=TChain("image2d_fake_plane%d_tree" % plane)
    ch.AddFile("fakedata.root")
    ch.GetEntry(0)
    exec('img = ch.image2d_fake_plane%d_branch.Image2DArray()[0]' % plane)
    arr = larcv.as_ndarray(img)
    
    fig,ax = plt.subplots(figsize=(12,8))
    plt.imshow(arr,vmin=0,vmax=1)
    plt.show()
